# %%
import sys
from pathlib import Path

import datetime
import pandas as pd
import f90nml

# %%
PROJ_DIR = Path.cwd().parent
sys.path.append(PROJ_DIR / 'tools')

from helpers import run_teb, load_txt, get_date_params

# %%
path_to_case_dir = PROJ_DIR / 'tests' / 'CAPITOUL'
path_to_teb_exe = PROJ_DIR / 'build' / 'driver'

# %%
run_teb(path_to_case_dir, path_to_teb_exe)
# Out:
# Running case: CAPITOUL

# %%
case_nml = f90nml.read(path_to_case_dir / 'input.nml')
start, freq = get_date_params(case_nml)
df_out = load_txt(path_to_case_dir / 'output', start, freq, tz='UTC')

# %%
df_out[['HVAC_COOL']].plot()
# Out:
# /home/david/miniconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,
